# %% [markdown]
# # Read shapefile
#
# ## Example 1: NYS county subdivision boundaries

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

gdf = gpd.read_file("./data/tl_2016_36_cousub/tl_2016_36_cousub.shp")

gdf.head()
# Out:
#   STATEFP COUNTYFP COUSUBFP  COUSUBNS       GEOID       NAME        NAMELSAD  \
# 0      36      017    55959  00979335  3601755959     Oxford     Oxford town
# 1      36      017    57507  00979360  3601757507  Pharsalia  Pharsalia town
# 2      36      017    58288  00979370  3601758288    Pitcher    Pitcher town
# 3      36      017    59817  00979398  3601759817    Preston    Preston town
# 4      36      017    66894  00979490  3601766894  Sherburne  Sherburne town
#
#   LSAD CLASSFP  MTFCC CNECTAFP NECTAFP NCTADVFP FUNCSTAT      ALAND  AWATER  \
# 0   43      T1  G4040     None    None     None        A  155563470  911062
# 1   43      T1  G4040     None    None     None        A  100533128  774336
# 2   43      T1  G4040     None    None     None        A   73723336   37391
# 3   43      T1  G4040     None    None     None        A   90327313  443458
# 4   43      T1  G4040     None    None     None        A  112803620   51669
#
#       INTPTLAT      INTPTLON  \
# ...

# %%
gdf.shape
# Out:
# (1023, 19)

# %%
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# ...

# %%
gdf.columns
# Out:
# Index(['BoroCode', 'BoroName', 'Shape_Leng', 'Shape_Area', 'geometry'], dtype='object')

# %%
sns.set_style("white")
gdf.plot(column="ALAND", cmap='viridis', figsize=(8,8), alpha=0.8)

# plt.axis('off')
# Out:
# <Axes: >

# %%
# Plot Brookhaven Town

gdf[gdf['NAME'].str.contains("Brookhaven")].plot(column="ALAND", figsize=(8,8), alpha=0.4)
# Out:
# <Axes: >

# %% [markdown]
# ## Exmaple 2: Chicago population

# %%
import geopandas as gpd
import geodatasets
import seaborn as sns
import matplotlib.pyplot as plt

chicago = gpd.read_file(geodatasets.get_path("geoda.chicago_commpop"))

chicago.head()
# Out:
#          community  NID  POP2010  POP2000  POPCH   POPPERCH  popplus  popneg  \
# 0          DOUGLAS   35    18238    26470  -8232 -31.099358        0       1
# 1          OAKLAND   36     5918     6110   -192  -3.142390        0       1
# 2      FULLER PARK   37     2876     3420   -544 -15.906433        0       1
# 3  GRAND BOULEVARD   38    21929    28006  -6077 -21.698922        0       1
# 4          KENWOOD   39    17841    18363   -522  -2.842673        0       1
#
#                                             geometry
# 0  MULTIPOLYGON (((-87.60914 41.84469, -87.60915 ...
# 1  MULTIPOLYGON (((-87.59215 41.81693, -87.59231 ...
# 2  MULTIPOLYGON (((-87.6288 41.80189, -87.62879 4...
# 3  MULTIPOLYGON (((-87.60671 41.81681, -87.6067 4...
# 4  MULTIPOLYGON (((-87.59215 41.81693, -87.59215 ...

# %%
sns.set_style("white")
chicago.plot(column="POP2010")
# Out:
# <Axes: >

# %% [markdown]
# # Read geojson

# %%
import geopandas as gpd
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import contextily as cx

nyc = gpd.read_file("./data/nyc.geojson")
nyc.head()
# Out:
#    OBJECTID CTLabel BoroCode   BoroName  CT2020 BoroCT2020 CDEligibil  \
# 0         1       1        1  Manhattan  000100    1000100          I
# 1         2   22.01        1  Manhattan  002201    1002201          E
# 2         3   26.02        1  Manhattan  002602    1002602          E
# 3         4      28        1  Manhattan  002800    1002800          E
# 4         5      34        1  Manhattan  003400    1003400          I
#
#                                              NTAName NTA2020 CDTA2020  \
# 0  The Battery-Governors Island-Ellis Island-Libe...  MN0191     MN01
# 1                                    Lower East Side  MN0302     MN03
# 2                                       East Village  MN0303     MN03
# 3                                       East Village  MN0303     MN03
# 4                                       East Village  MN0303     MN03
#
#                                             CDTANAME        GEOID  PUMA  \
# ...

# %%
ax=nyc.plot(column='Shape__Length', figsize=(10,10), alpha=0.8, cmap='inferno')
cx.add_basemap(ax, crs=nyc.crs)
