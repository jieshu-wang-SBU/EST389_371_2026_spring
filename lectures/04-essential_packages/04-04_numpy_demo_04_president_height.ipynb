# %% [markdown]
# # An example: US presidents' height
# (data and example structure come from _Python Data Science Handbook (2nd edition)_ by Jake VanderPlas)

# %%
import numpy as np
import pandas as pd

data = pd.read_csv("data/president_heights.csv")

# %% [markdown]
# ## extract height data from the dataframe as a numpy array

# %%
heights = np.array(data["height(cm)"])
print(heights)
# Out:
# [189 170 189 163 183 171 185 168 173 183 173 173 175 178 183 193 178 173
#  174 183 183 168 170 178 182 180 183 178 182 188 175 179 183 193 182 183
#  177 185 188 188 182 185 191 182]

# %% [markdown]
# ## compute summary statistics using the numpy functions we learnt

# %%
print("Mean height:       ", heights.mean())
print("Standard deviation:", heights.std())
print("Minimum height:    ", heights.min())
print("Maximum height:    ", heights.max())
# Out:
# Mean height:        180.04545454545453
# Standard deviation: 6.983599441335736
# Minimum height:     163
# Maximum height:     193

# %%
print("25th percentile:   ", np.percentile(heights, 25))
print("Median:            ", np.median(heights))
print("75th percentile:   ", np.percentile(heights, 75))
# Out:
# 25th percentile:    174.75
# Median:             182.0
# 75th percentile:    183.5

# %% [markdown]
# ## Convert the height to feet and inches
#
# - $1 \space inch = 2.54 \space cm$
# - $1 \space foot = 12 \space inches$

# %%
heights_in_inches = heights/2.54
print(heights_in_inches)
# Out:
# [74.40944882 66.92913386 74.40944882 64.17322835 72.04724409 67.32283465
#  72.83464567 66.14173228 68.11023622 72.04724409 68.11023622 68.11023622
#  68.8976378  70.07874016 72.04724409 75.98425197 70.07874016 68.11023622
#  68.50393701 72.04724409 72.04724409 66.14173228 66.92913386 70.07874016
#  71.65354331 70.86614173 72.04724409 70.07874016 71.65354331 74.01574803
#  68.8976378  70.47244094 72.04724409 75.98425197 71.65354331 72.04724409
#  69.68503937 72.83464567 74.01574803 74.01574803 71.65354331 72.83464567
#  75.19685039 71.65354331]

# %%
heights_in_feet = heights_in_inches // 12
heights_remainder_inches = heights_in_inches % 12

print("Height in feet")
print(heights_in_feet)
print("\nremainding inches")
print(heights_remainder_inches)
# Out:
# Height in feet
# [6. 5. 6. 5. 6. 5. 6. 5. 5. 6. 5. 5. 5. 5. 6. 6. 5. 5. 5. 6. 6. 5. 5. 5.
#  5. 5. 6. 5. 5. 6. 5. 5. 6. 6. 5. 6. 5. 6. 6. 6. 5. 6. 6. 5.]
#
# remainding inches
# [ 2.40944882  6.92913386  2.40944882  4.17322835  0.04724409  7.32283465
#   0.83464567  6.14173228  8.11023622  0.04724409  8.11023622  8.11023622
#   8.8976378  10.07874016  0.04724409  3.98425197 10.07874016  8.11023622
#   8.50393701  0.04724409  0.04724409  6.14173228  6.92913386 10.07874016
#  11.65354331 10.86614173  0.04724409 10.07874016 11.65354331  2.01574803
#   8.8976378  10.47244094  0.04724409  3.98425197 11.65354331  0.04724409
#   9.68503937  0.83464567  2.01574803  2.01574803 11.65354331  0.83464567
#   3.19685039 11.65354331]

# %%
# Let's print out the height in feet
# note: \ escapes the following double quotation sign.

for i in range(0, len(heights)):
    name = data.iloc[i]['name']
    height_in_cm = heights[i]
    height_in_feet = heights_in_feet[i]
    height_remainder_inches = heights_remainder_inches[i]
    print(f"{name}'s is {height_in_cm} cm tall,"
          f"equivalent to {height_in_feet:.0f}'{height_remainder_inches:.0f}\"")
# Out:
# George Washington's is 189 cm tall,equivalent to 6'2"
# John Adams's is 170 cm tall,equivalent to 5'7"
# Thomas Jefferson's is 189 cm tall,equivalent to 6'2"
# James Madison's is 163 cm tall,equivalent to 5'4"
# James Monroe's is 183 cm tall,equivalent to 6'0"
# John Quincy Adams's is 171 cm tall,equivalent to 5'7"
# Andrew Jackson's is 185 cm tall,equivalent to 6'1"
# Martin Van Buren's is 168 cm tall,equivalent to 5'6"
# William Henry Harrison's is 173 cm tall,equivalent to 5'8"
# John Tyler's is 183 cm tall,equivalent to 6'0"
# James K. Polk's is 173 cm tall,equivalent to 5'8"
# Zachary Taylor's is 173 cm tall,equivalent to 5'8"
# Millard Fillmore's is 175 cm tall,equivalent to 5'9"
# Franklin Pierce's is 178 cm tall,equivalent to 5'10"
# James Buchanan's is 183 cm tall,equivalent to 6'0"
# Abraham Lincoln's is 193 cm tall,equivalent to 6'4"
# Andrew Johnson's is 178 cm tall,equivalent to 5'10"
# Ulysses S. Grant's is 173 cm tall,equivalent to 5'8"
# Rutherford B. Hayes's is 174 cm tall,equivalent to 5'9"
# James A. Garfield's is 183 cm tall,equivalent to 6'0"
# Chester A. Arthur's is 183 cm tall,equivalent to 6'0"
# Benjamin Harrison's is 168 cm tall,equivalent to 5'6"
# William McKinley's is 170 cm tall,equivalent to 5'7"
# Theodore Roosevelt's is 178 cm tall,equivalent to 5'10"
# William Howard Taft's is 182 cm tall,equivalent to 5'12"
# Woodrow Wilson's is 180 cm tall,equivalent to 5'11"
# Warren G. Harding's is 183 cm tall,equivalent to 6'0"
# Calvin Coolidge's is 178 cm tall,equivalent to 5'10"
# Herbert Hoover's is 182 cm tall,equivalent to 5'12"
# Franklin D. Roosevelt's is 188 cm tall,equivalent to 6'2"
# Harry S. Truman's is 175 cm tall,equivalent to 5'9"
# Dwight D. Eisenhower's is 179 cm tall,equivalent to 5'10"
# John F. Kennedy's is 183 cm tall,equivalent to 6'0"
# Lyndon B. Johnson's is 193 cm tall,equivalent to 6'4"
# Richard Nixon's is 182 cm tall,equivalent to 5'12"
# Gerald Ford's is 183 cm tall,equivalent to 6'0"
# Jimmy Carter's is 177 cm tall,equivalent to 5'10"
# Ronald Reagan's is 185 cm tall,equivalent to 6'1"
# George H. W. Bush's is 188 cm tall,equivalent to 6'2"
# Bill Clinton's is 188 cm tall,equivalent to 6'2"
# George W. Bush's is 182 cm tall,equivalent to 5'12"
# Barack Obama's is 185 cm tall,equivalent to 6'1"
# Donald Trump's is 191 cm tall,equivalent to 6'3"
# Joseph Biden's is 182 cm tall,equivalent to 5'12"

# %% [markdown]
# ## Optional: Plot the height

# %%
import matplotlib.pyplot as plt

plt.hist(heights, bins=10, rwidth=0.9)
plt.title('Height Distribution of US Presidents')
plt.xlabel('height (cm)')
plt.ylabel('number')

# if you want to add a vertical line to indicate 6 feet
# plt.axvline(x=182.8, color='r', linestyle='--', linewidth=2)
# Out:
# Text(0, 0.5, 'number')
