# %% [markdown]
# # Unifying and Fixing Data types
#
# The idea is:
# - When numbers are stored as strings, use `pd.to_numeric(column, errors="coerce")`
# - However, inspect data and do necessary cleaning first, such as remove `$` sign
#
# ## Example 1: unifying data typr
# ### Let's create a messy dataset first

# %%
import pandas as pd

df = pd.DataFrame({
    "product": ["Laptop", "Phone", "Tablet", "Monitor", "Keyboard"],
    "price": ["1200", "800", "N/A", "350", "unknown"]
})

print("Original Data:")
print(df)

print("\nData types:")
print(df.dtypes)

print("\n notice the type of price is object, not numeric")
# Out:
# Original Data:
#     product    price
# 0    Laptop     1200
# 1     Phone      800
# 2    Tablet      N/A
# 3   Monitor      350
# 4  Keyboard  unknown
#
# Data types:
# product    object
# price      object
# dtype: object

# %% [markdown]
# ### Let's try Converting to Numeric

# %%
# errors="coerce" is important here, it means if value cannot be converted, turn it into NaN.

df["price"] = pd.to_numeric(df["price"], errors="coerce")

print("After Conversion:")
print(df)

print("\nData types:")
print(df.dtypes)

# %% [markdown]
# ### Why This Is Helpful?
#
# Now you can detect problematic entries. This helps identify:
# - Data entry errors
# - Unexpected values
# - Cleaning needed

# %%
print("Rows with invalid price data:")
print(df[df["price"].isna()])

# %% [markdown]
# ### What If We Didn’t Use errors="coerce"?
#
# This would raise an error, because string "Unknown" is unable to be convert to numeric

# %%
df_test = pd.DataFrame({
    "price": ["1200", "800", "Unknown"]
})

pd.to_numeric(df_test["price"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/lib.pyx:2407, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Unknown"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 5
#       1 df_test = pd.DataFrame({
#       2     "price": ["1200", "800", "Unknown"]
#       3 })
# ----> 5 pd.to_numeric(df_test["price"])
#
# File ~/PycharmProjects/EST389_371_2026_spring/.venv/lib/python3.11/site-packages/pandas/core/tools/numeric.py:235, in to_numeric(arg, errors, downcast, dtype_backend)
#     233 coerce_numeric = errors not in ("ignore", "raise")
#     234 try:
# --> 235     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]
#     236         values,
#     237         set(),
#     238         coerce_numeric=coerce_numeric,
#     239         convert_to_masked_nullable=dtype_backend is not lib.no_default
#     240         or isinstance(values_dtype, StringDtype)
#     241         and values_dtype.na_value is libmissing.NA,
#     242     )
#     243 except (ValueError, TypeError):
#     244     if errors == "raise":
#
# File pandas/_libs/lib.pyx:2449, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Unknown" at position 2

# %% [markdown]
# ## Example 2: removing currency symbols
#
# Sometimes prices look like:

# %%
df2 = pd.DataFrame({
    "price": ["$1200", "$800", "$350"]
})

print(df2)
print(df2.dtypes)
# Out:
#    price
# 0  $1200
# 1   $800
# 2   $350
# price    object
# dtype: object

# %% [markdown]
# ### First remove $

# %%
df2["price"] = df2["price"].str.replace("$", "", regex=False)

print(df2)
print(df.dtypes)
# Out:
#   price
# 0  1200
# 1   800
# 2   350
# product     object
# price      float64
# dtype: object

# %% [markdown]
# ### Then convert the strings to numeric

# %%
df2["price"] = pd.to_numeric(df2["price"], errors="coerce")

print(df2)
print(df2.dtypes)
# Out:
#    price
# 0   1200
# 1    800
# 2    350
# price    int64
# dtype: object
