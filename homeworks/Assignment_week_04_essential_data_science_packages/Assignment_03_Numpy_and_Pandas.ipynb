# %% [markdown]
# # EST 389 – Homework: Essential Python Packages (NumPy & Pandas)
#
# **Total Points: 5**
#
# This homework practices essential operations in NumPy and Pandas.
#
# Important:
# - Follow the required variable names exactly.
# - Your notebook must run from top to bottom without errors.
#
# ## Problem 1 (1 Point): Create and Compute Numpy Arrays
# ### Problem 1.1 (0.5 point)
#
# - First, import numpy as np
# - Create a NumPy array named `arr` of 10 integers starting from 0 to 9 (including 9)

# %%
import numpy as np

# %% [markdown]
# ### Problem 1.2 (0.5 point)
# Create two variables in this cell:
# - Create a new variable named `mean_value` that stores the average value of the array `arr`.
#     - hint: .mean(), .min(), and .max() are used to compute numpy arrays' average, minimum, and maximum values.
# - Create a new variable named `arr_shape` that stores the shape of the array `arr`.
#     - hint: ndarray's structural attributes (ndim, shape, size)

# %% [markdown]
# ## Problem 2 (1 point): `ndarray` operations
# ### Problem 2.1 (0.5 point)
# - Create a new array containing elements from the beginning up to index 4 (excluding index 4) of array `arr`.
# - Name of the array should be: `first_part`

# %% [markdown]
# ### Problem 2.2 (0.5 point)
# - Create a new array, of which every element is equal to the element in array `arr` plus 5
# - Name of the new array should be: `plus_five`

# %% [markdown]
# ## Problem 3 (1 point): Create a pandas DataFrame
#
# Create a Pandas DataFrame with the following columns and values:
#
# - `"name"`: ["Alice", "Bob", "Charlie", "David", "Eva"]
# - `"score"`: [75, 58, 92, 64, 47]
#
# Instructions:
# - Name the DataFrame variable: `df`

# %%
import pandas as pd

# %% [markdown]
# ## Problem 4 (1 point): Inspect the DataFrame
# ### Problem 4.1 (0.5 point)
# Create a new variable named `shape_df` that stores the shape of the DataFrame `df`

# %% [markdown]
# ### Problem 4.2 (0.5 point)
# Create a new variable named `average_score` that stores the average score of the five people

# %% [markdown]
# ## Problem 5 (1 point): Select and Filter DataFrame
# ### Problem 5.1 (0.5 point)
# - Create a new variable that stores the value located at the first row and first column of the DataFrame `df`.
# - Name of the variable should be: `first_cell_value`

# %% [markdown]
# ### Problem 5.2 (0.5 point)
# - Create a new DataFrame that contains only the rows where `"score"` is greater than or equal to 60.
# - Name the variable: `df_passing`
